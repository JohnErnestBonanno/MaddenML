# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import tree
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %matplotlib inline

# %%
df = pd.read_csv("player_stat_18.csv")

# %%
#split positions into offense, defense, and special teams
off_pos_list = ['C','FB','HB','LG','LT','QB','RG','RT','TE','WR']
def_pos_list = ['CB','DT','FS','LE','LOLB','MLB','RE','ROLB','SS']
sTeams_pos_list = ['K','P']

# %%
#Creates a new function to put each position into its own category.  
def define_pos(x):
    if x in off_pos_list:
        return('Off')
    if x in def_pos_list:
        return('Def')
    if x in sTeams_pos_list:
        return('sTeams')
    else:
        return("Missing")

# %%
df['pos_class'] = df['Position'].apply(define_pos)

# %%
extra_cols = ['Dev Trait','Last Name', 'First Name', 'Position','Birthdate','Years Pro','College','portraitId','Handedness']

#extra columns
df.drop(extra_cols, inplace=True, axis=1)

# %%
df.head()
# Out:
#    Overall Rating  Speed  Acceleration  Strength  Agility  Awareness  \
# 0              91     82            88        79       78         85
# 1              88     83            87        80       83         90
# 2              85     89            91        66       87         92
# 3              83     75            82        78       78         91
# 4              83     88            90        81       91         84
#
#    Catching  Carrying  Throw Power  Throw Accuracy    ...      \
# 0        70        77           35              32    ...
# 1        65        50           22              22    ...
# 2        93        74           35              35    ...
# 3        49        40           34              40    ...
# 4        68        82           35              30    ...
#
#    Throw Accuracy Mid  Throw Accuracy Deep  Play Action  Throw on the Run  \
# 0                  15                   10           10                10
# 1                   6                    6            6                 6
# 2                  10                    6            6                10
# 3                   6                    6            6                 6
# 4                  30                   20           15                15
#
#    Height  Weight  Age  Total Salary  Signing Bonus  pos_class
# 0      73     240   26      15600000        5000000        Off
# 1      72     242   29      42750000       10000000        Def
# 2      72     211   31      35000000        7000000        Off
# 3      71     255   33       5000000        2000000        Def
# 4      72     228   26       3600000        1600000        Off
#
# [5 rows x 55 columns]

# %%
le = preprocessing.LabelEncoder()
le.fit(df.pos_class)
# Out:
# LabelEncoder()

# %%
list(le.classes_)
# Out:
# ['Def', 'Off', 'sTeams']

# %%
le.transform(df.pos_class)
# Out:
# array([1, 0, 1, ..., 1, 0, 1], dtype=int64)

# %%
df.pos_class = le.transform(df.pos_class)

# %%
df.head()
# Out:
#    Overall Rating  Speed  Acceleration  Strength  Agility  Awareness  \
# 0              91     82            88        79       78         85
# 1              88     83            87        80       83         90
# 2              85     89            91        66       87         92
# 3              83     75            82        78       78         91
# 4              83     88            90        81       91         84
#
#    Catching  Carrying  Throw Power  Throw Accuracy    ...      \
# 0        70        77           35              32    ...
# 1        65        50           22              22    ...
# 2        93        74           35              35    ...
# 3        49        40           34              40    ...
# 4        68        82           35              30    ...
#
#    Throw Accuracy Mid  Throw Accuracy Deep  Play Action  Throw on the Run  \
# 0                  15                   10           10                10
# 1                   6                    6            6                 6
# 2                  10                    6            6                10
# 3                   6                    6            6                 6
# 4                  30                   20           15                15
#
#    Height  Weight  Age  Total Salary  Signing Bonus  pos_class
# 0      73     240   26      15600000        5000000          1
# 1      72     242   29      42750000       10000000          0
# 2      72     211   31      35000000        7000000          1
# 3      71     255   33       5000000        2000000          0
# 4      72     228   26       3600000        1600000          1
#
# [5 rows x 55 columns]

# %%
df.iloc[1768] #this guy is def a kicker

# %%
y = df.pos_class
#create training and testing variables
x_train, x_test, y_train, y_test = train_test_split(df,y,test_size = 0.2)
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
pred = clf.predict(x_test)

# %%
acc = accuracy_score(pred, y_test)
print(acc)

# %%
print(pred)

# %%
EDA_labels = ['Kick Power','Pursuit','Tackle','Carrying','Run Block','Height','Weight','pos_class']
df2 = df[EDA_labels]

# %%
df2.head()
# Out:
#    Kick Power  Pursuit  Tackle  Carrying  Run Block  Height  Weight  pos_class
# 0          19       48      45        77         71      73     240          1
# 1          10       94      92        50         45      72     242          0
# 2          30       35      35        74         62      72     211          1
# 3          20       88      77        40         45      71     255          0
# 4          25       50      25        82         64      72     228          1

# %%
y = df2.pos_class
#create training and testing variables
x_train, x_test, y_train, y_test = train_test_split(df2,y,test_size = 0.2)
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
pred = clf.predict(x_test)

# %%
acc = accuracy_score(pred, y_test)
print(acc)
# Out:
# 1.0

# %%
x_train.head()
# Out:
#       Kick Power  Pursuit  Tackle  Carrying  Run Block  Height  Weight  \
# 926           22       80      78        48         45      76     267
# 2117          35       70      57        70         76      76     320
# 759           21       34      20        62         62      70     185
# 1025          25       57      51        65         47      74     212
# 2318          17       76      73        45         45      72     297
#
#       pos_class
# 926           0
# 2117          1
# 759           1
# 1025          1
# 2318          0
